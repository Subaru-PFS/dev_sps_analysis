# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
# import LAM library for logbook, data analysis...
from pfs.lam.sacFileHandling import Logbook, constructFilelist
import pfs.lam.imageAnalysis as imeas
from pfs.lam.slitFocusAnalysis import *
from pfs.lam.style import colors

# %%
from matplotlib import style
style.use('ggplot')

# %%
imgPath = '/home/pfs/shared/Pictures/SM3/slitAlign/'

# %%
smId = 3

# %%
# filepath of data model
pmodel = os.environ['LAM_SPS_ANALYSIS_DIR']+"/notebooks/optical/input/slit"
file = 'slit-defParam-Ouverture100-fiber65.csv'

# %%
zemaxData = pd.read_csv('%s/%s' % (pmodel, file), delimiter=" ")
zemaxMidFit = imeas.fitparabola(x=zemaxData.Slitdefocus, y=zemaxData.MidFiber, deg=15, focus='max')
zemaxEndFit = imeas.fitparabola(x=zemaxData.Slitdefocus, y=zemaxData.ExtremeFiber, deg=15, focus='max')

# %%
experiments = pd.read_sql_query('select * from Experiment where type="slitAlignment" order by experimentId desc',
                                con='sqlite:////data/ait/experimentLog-sac.db', index_col='experimentId')

experiments['exptime'] = [Logbook.getParameter(experimentId, 'exptime') for experimentId in experiments.index]
experiments['fiber'] = [Logbook.getParameter(experimentId, 'fiber', doRaise=False) for experimentId in experiments.index]

# %% [raw]
# fiberId = {126:'engtopmid',127:'engbotmid',128:'engtopmid',129:'engtopmid', 130:'engtopmid', 131:'engbotmid', 132:'engbotmid', 133:'engbotmid', 135:'engtopmid'}
#
# experiments['fiber']  = [experiments.fiber[experimentId] if experimentId not in fiberId.keys() else fiberId[experimentId] for experimentId in experiments.index ]

# %%
experiments
# Out:
#                             name  visitStart  visitEnd           type  \
# experimentId
# 455           SM3_Slit_Alignment       13759     13759  slitAlignment
# 454           SM3_Slit_Alignment       13699     13758  slitAlignment
# 453           SM3_Slit_Alignment       13639     13698  slitAlignment
# 452           SM3_Slit_Alignment       13579     13638  slitAlignment
# 451           SM3_Slit_Alignment       13519     13578  slitAlignment
# ...                          ...         ...       ...            ...
# 40                    first_test        1199      1258  slitAlignment
# 39                    first_test        1196      1198  slitAlignment
# 38                    first_test        1132      1191  slitAlignment
# 37                    first_test        1122      1131  slitAlignment
# 36                    first_test        1112      1121  slitAlignment
#
#                                                          cmdStr  \
# experimentId
# 455           spsait slit align exptime=4.0 position=-1.5,2....
# 454           spsait slit align exptime=6.0 position=-1.5,2....
# 453           spsait slit align exptime=6.0 position=-1.5,2....
# 452           spsait slit align exptime=6.0 position=-1.5,2....
# 451           spsait slit align exptime=6.0 position=-1.5,2....
# ...                                                         ...
# 40            slit throughfocus exptime=3.0 lowBound=-0.5 up...
# 39            slit throughfocus exptime=3.0 lowBound=-0.5 up...
# 38            slit throughfocus exptime=6.0 lowBound=-0.5 up...
# 37            slit throughfocus exptime=6.0 lowBound=-0.5 up...
# 36            slit throughfocus exptime=6.0 lowBound=-0.5 up...
#
#                         comments     anomalies            startdate  \
# experimentId
# 455           halogen mask 125mm                2021-02-18T08:57:57
# 454           halogen mask 125mm                2021-02-17T11:48:14
# 453           halogen mask 125mm                2021-02-17T11:23:21
# 452           halogen mask 125mm                2021-02-17T10:58:06
# 451           halogen mask 125mm                2021-02-17T10:33:22
# ...                          ...           ...                  ...
# 40                                              2018-07-16T17:07:37
# 39                                light was on  2018-07-16T17:05:53
# 38                                              2018-07-16T16:02:19
# 37                                              2018-07-16T15:55:06
# 36                                              2018-07-16T15:22:33
#
#                                                        cmdError exptime  \
# experimentId
# 455           text='command failed: UserWarning('Stop reques...     4.0
# 454                                                                 6.0
# 453                                                                 6.0
# 452                                                                 6.0
# 451                                                                 6.0
# ...                                                         ...     ...
# 40                                                         None     3.0
# 39                                                         None     3.0
# 38                                                         None     6.0
# 37                                                         None     6.0
# 36                                                         None     6.0
#
#                   fiber
# experimentId
# 455           engtopend
# 454           engbotend
# 453           engbotmid
# 452           engtopmid
# 451           engtopend
# ...                 ...
# 40            engtopmid
# 39            engtopmid
# 38            engtopmid
# 37            engtopmid
# 36            engtopmid
#
# [236 rows x 11 columns]

# %%
experiments.cmdStr[447]
# Out:
# 'spsait slit align exptime=1.0 position=-1.5,2.5,60 duplicate=1 fiber=engtopend'

# %% [markdown]
# https://rendez-vous.renater.fr/MacabreMonstersContemplateSteadily#config.callDisplayName=%22Jitsi%20Meeting%22## Data required :
# To be able to find the right focus, some data acquisition is required.
#
# you need to use ics_spsaitActor to perform your sequence
#
# example : <b>slit throughfocus exptime=6.0 lowBound=-0.5 upBound=1.5 fiber=engbotend nbPosition=10 duplicate=1 </b>
#
# -0.5 : 1.5 is the range of the slit focus

# %% [markdown]
# ## Input Parameters :
# The only parameters needed is the experimentIds that match your data acquisition sequence

# %%
com = True
doBck =True
corrector = False
experimentIds = [447,448,449,450]

head = 0
tail = 0
#bck_expId = 260

dfs = []

# %%
threshold = 300
radius = 60
doPrint = False
doPlot = False
roi_size = 150

fwhm_radius = radius
fwhm_method = 'gaussian'

# %%
for experimentId in experimentIds:
    visitStart, visitEnd = Logbook.visitRange(experimentId=experimentId)
    filelist = constructFilelist(visitStart=visitStart, visitEnd=visitEnd)
    duplicate = int(Logbook.getParameter(experimentId=experimentId, param='duplicate'))
    filelist = filelist[head*duplicate:len(filelist)-tail*duplicate]
    guessedPos = getSlitPosFromMove(experimentId)
    
    fiberId = Logbook.getParameter(experimentId, 'fiber', doRaise=False)

    res = []
    for i in range(len(filelist) // duplicate):
        hdr, data = stackedImage(filelist=filelist, ind=i, duplicate=duplicate, doBck=doBck)
    #    peak = getPeakData(data, com=com, doBck=False, doPlot=doPlot, doPrint=doPrint)
        if doPlot:
            plt.imshow(data, origin = 'lower', cmap = 'gray', vmin=300, vmax=800)
        calc = iqcalc.IQCalc(None)
        peaks = calc.find_bright_peaks(data, threshold=threshold, radius=radius)
        objlist = calc.evaluate_peaks(peaks, data, fwhm_radius=radius, cb_fn=None, ev_intr=None, fwhm_method='gaussian')
        if doPrint: 
            print(len(objlist))


        objlist = [elem for elem in objlist if elem['fwhm'] > 15]
        objlist = [elem for elem in objlist if (elem['fwhm_x'] > 15) and (elem['fwhm_y'] > 15)]
        objlist = [elem for elem in objlist if threshold < elem['brightness'] < 50000]
        for obj in objlist :
            plt.scatter(obj['oid_x'],obj['oid_y'],s=80,c='red',marker='x',label='peak', edgecolors=None)
        if doPlot:
            plt.show()

        if doPrint: 
            print(f"Object detected after filtering: {len(objlist)}")
        if not objlist:
            print('peak has not been properly detected')
            obj ={"px": np.nan,
                  "py": np.nan,
                  "oid_x": np.nan,
                  "oid_y": np.nan,
                  "EE20" : np.nan
                 }
            dict(obj)
        else:
            maxi = np.argmax([imeas.getEE(image=data, cx=peak['oid_x'], cy=peak['oid_y'], ee_size=20, roi_size=300)[0] for peak in objlist])
            cx = objlist[maxi]['oid_x']
            cy = objlist[maxi]['oid_y']

            peak = imeas.getPeakData(data, cx, cy, EE=[20], roi_size=roi_size, doPlot=False, com=com, fwhm_radius=fwhm_radius, fwhm_method=fwhm_method)
            peak['experimentId'] = experimentId
            peak['fiber'] = fiberId
        try:
            fca_x = hdr['FCA_X']
        except KeyError:
            fca_x = guessedPos[i]

        peak['fca_x'] = fca_x
        res.append(peak)
        if doPlot:
            plt.show()
        if doPrint:
            print("\n")
        df = pd.DataFrame(res)
    dfs.append(df)

cube = pd.concat(dfs)
# Out:
# 0
# /data/ait/sac/2021-02-16/SAC013255.fits
# 1
# /data/ait/sac/2021-02-16/SAC013256.fits
# 2
# /data/ait/sac/2021-02-16/SAC013257.fits
# 3
# /data/ait/sac/2021-02-16/SAC013258.fits
# 4
# /data/ait/sac/2021-02-16/SAC013259.fits
# 5
# /data/ait/sac/2021-02-16/SAC013260.fits
# 6
# /data/ait/sac/2021-02-16/SAC013261.fits
# 7
# /data/ait/sac/2021-02-16/SAC013262.fits
# 8
# /data/ait/sac/2021-02-16/SAC013263.fits
# 9
# /data/ait/sac/2021-02-16/SAC013264.fits
# 10
# /data/ait/sac/2021-02-16/SAC013265.fits
# 11
# /data/ait/sac/2021-02-16/SAC013266.fits
# 12
# /data/ait/sac/2021-02-16/SAC013267.fits
# 13
# /data/ait/sac/2021-02-16/SAC013268.fits
# 14
# /data/ait/sac/2021-02-16/SAC013269.fits
# 15
# /data/ait/sac/2021-02-16/SAC013270.fits
# 16
# /data/ait/sac/2021-02-16/SAC013271.fits
# 17
# /data/ait/sac/2021-02-16/SAC013272.fits
# 18
# /data/ait/sac/2021-02-16/SAC013273.fits
# 19
# /data/ait/sac/2021-02-16/SAC013274.fits
# 20
# /data/ait/sac/2021-02-16/SAC013275.fits
# 21
# /data/ait/sac/2021-02-16/SAC013276.fits
# 22
# /data/ait/sac/2021-02-16/SAC013277.fits
# 23
# /data/ait/sac/2021-02-16/SAC013278.fits
# 24
# /data/ait/sac/2021-02-16/SAC013279.fits
# 25
# /data/ait/sac/2021-02-16/SAC013280.fits
# 26
# /data/ait/sac/2021-02-16/SAC013281.fits
# 27
# /data/ait/sac/2021-02-16/SAC013282.fits
# 28
# /data/ait/sac/2021-02-16/SAC013283.fits
# 29
# /data/ait/sac/2021-02-16/SAC013284.fits
# 30
# /data/ait/sac/2021-02-16/SAC013285.fits
# 31
# /data/ait/sac/2021-02-16/SAC013286.fits
# 32
# /data/ait/sac/2021-02-16/SAC013287.fits
# 33
# /data/ait/sac/2021-02-16/SAC013288.fits
# 34
# /data/ait/sac/2021-02-16/SAC013289.fits
# 35
# /data/ait/sac/2021-02-16/SAC013290.fits
# 36
# /data/ait/sac/2021-02-16/SAC013291.fits
# 37
# /data/ait/sac/2021-02-16/SAC013292.fits
# 38
# /data/ait/sac/2021-02-16/SAC013293.fits
# 39
# /data/ait/sac/2021-02-16/SAC013294.fits
# 40
# /data/ait/sac/2021-02-16/SAC013295.fits
# 41
# /data/ait/sac/2021-02-16/SAC013296.fits
# 42
# /data/ait/sac/2021-02-16/SAC013297.fits
# 43
# /data/ait/sac/2021-02-16/SAC013298.fits
# 44
# /data/ait/sac/2021-02-16/SAC013299.fits
# 45
# /data/ait/sac/2021-02-16/SAC013300.fits
# 46
# /data/ait/sac/2021-02-16/SAC013301.fits
# 47
# /data/ait/sac/2021-02-16/SAC013302.fits
# 48
# /data/ait/sac/2021-02-16/SAC013303.fits
# 49
# /data/ait/sac/2021-02-16/SAC013304.fits
# 50
# /data/ait/sac/2021-02-16/SAC013305.fits
# 51
# /data/ait/sac/2021-02-16/SAC013306.fits
# /software/drp/python/miniconda3-4.5.12/envs/lsst-scipipe-1172c30/lib/python3.7/site-packages/scipy/optimize/minpack.py:447: RuntimeWarning: Number of calls to function has reached maxfev = 800.
#   warnings.warn(errors[info][0], RuntimeWarning)
# 52
# /data/ait/sac/2021-02-16/SAC013307.fits
# peak has not been properly detected
# 53
# /data/ait/sac/2021-02-16/SAC013308.fits
# peak has not been properly detected
# 54
# /data/ait/sac/2021-02-16/SAC013309.fits
# peak has not been properly detected
# 55
# /data/ait/sac/2021-02-16/SAC013310.fits
# peak has not been properly detected
# 56
# /data/ait/sac/2021-02-16/SAC013311.fits
# peak has not been properly detected
# 57
# /data/ait/sac/2021-02-16/SAC013312.fits
# peak has not been properly detected
# 58
# /data/ait/sac/2021-02-16/SAC013313.fits
# peak has not been properly detected
# 59
# /data/ait/sac/2021-02-16/SAC013314.fits
# peak has not been properly detected
# 0
# /data/ait/sac/2021-02-16/SAC013315.fits
# 1
# /data/ait/sac/2021-02-16/SAC013316.fits
# 2
# /data/ait/sac/2021-02-16/SAC013317.fits
# 3
# /data/ait/sac/2021-02-16/SAC013318.fits
# 4
# /data/ait/sac/2021-02-16/SAC013319.fits
# 5
# /data/ait/sac/2021-02-16/SAC013320.fits
# 6
# /data/ait/sac/2021-02-16/SAC013321.fits
# 7
# /data/ait/sac/2021-02-16/SAC013322.fits
# 8
# /data/ait/sac/2021-02-16/SAC013323.fits
# 9
# /data/ait/sac/2021-02-16/SAC013324.fits
# 10
# /data/ait/sac/2021-02-16/SAC013325.fits
# 11
# /data/ait/sac/2021-02-16/SAC013326.fits
# 12
# /data/ait/sac/2021-02-16/SAC013327.fits
# 13
# /data/ait/sac/2021-02-16/SAC013328.fits
# 14
# /data/ait/sac/2021-02-16/SAC013329.fits
# 15
# /data/ait/sac/2021-02-16/SAC013330.fits
# 16
# /data/ait/sac/2021-02-16/SAC013331.fits
# 17
# /data/ait/sac/2021-02-16/SAC013332.fits
# 18
# /data/ait/sac/2021-02-16/SAC013333.fits
# 19
# /data/ait/sac/2021-02-16/SAC013334.fits
# 20
# /data/ait/sac/2021-02-16/SAC013335.fits
# 21
# /data/ait/sac/2021-02-16/SAC013336.fits
# 22
# /data/ait/sac/2021-02-16/SAC013337.fits
# 23
# /data/ait/sac/2021-02-16/SAC013338.fits
# 24
# /data/ait/sac/2021-02-16/SAC013339.fits
# 25
# /data/ait/sac/2021-02-16/SAC013340.fits
# 26
# /data/ait/sac/2021-02-16/SAC013341.fits
# 27
# /data/ait/sac/2021-02-16/SAC013342.fits
# 28
# /data/ait/sac/2021-02-16/SAC013343.fits
# 29
# /data/ait/sac/2021-02-16/SAC013344.fits
# 30
# /data/ait/sac/2021-02-16/SAC013345.fits
# 31
# /data/ait/sac/2021-02-16/SAC013346.fits
# 32
# /data/ait/sac/2021-02-16/SAC013347.fits
# 33
# /data/ait/sac/2021-02-16/SAC013348.fits
# 34
# /data/ait/sac/2021-02-16/SAC013349.fits
# 35
# /data/ait/sac/2021-02-16/SAC013350.fits
# 36
# /data/ait/sac/2021-02-16/SAC013351.fits
# 37
# /data/ait/sac/2021-02-16/SAC013352.fits
# 38
# /data/ait/sac/2021-02-16/SAC013353.fits
# 39
# /data/ait/sac/2021-02-16/SAC013354.fits
# 40
# /data/ait/sac/2021-02-16/SAC013355.fits
# 41
# /data/ait/sac/2021-02-16/SAC013356.fits
# 42
# /data/ait/sac/2021-02-16/SAC013357.fits
# 43
# /data/ait/sac/2021-02-16/SAC013358.fits
# 44
# /data/ait/sac/2021-02-16/SAC013359.fits
# 45
# /data/ait/sac/2021-02-16/SAC013360.fits
# 46
# /data/ait/sac/2021-02-16/SAC013361.fits
# 47
# /data/ait/sac/2021-02-16/SAC013362.fits
# 48
# /data/ait/sac/2021-02-16/SAC013363.fits
# 49
# /data/ait/sac/2021-02-16/SAC013364.fits
# 50
# /data/ait/sac/2021-02-16/SAC013365.fits
# 51
# /data/ait/sac/2021-02-16/SAC013366.fits
# 52
# /data/ait/sac/2021-02-16/SAC013367.fits
# 53
# /data/ait/sac/2021-02-16/SAC013368.fits
# 54
# /data/ait/sac/2021-02-16/SAC013369.fits
# 55
# /data/ait/sac/2021-02-16/SAC013370.fits
# peak has not been properly detected
# 56
# /data/ait/sac/2021-02-16/SAC013371.fits
# 57
# /data/ait/sac/2021-02-16/SAC013372.fits
# peak has not been properly detected
# 58
# /data/ait/sac/2021-02-16/SAC013373.fits
# peak has not been properly detected
# 59
# /data/ait/sac/2021-02-16/SAC013374.fits
# peak has not been properly detected
# 0
# /data/ait/sac/2021-02-16/SAC013375.fits
# 1
# /data/ait/sac/2021-02-16/SAC013376.fits
# 2
# /data/ait/sac/2021-02-16/SAC013377.fits
# 3
# /data/ait/sac/2021-02-16/SAC013378.fits
# 4
# /data/ait/sac/2021-02-16/SAC013379.fits
# 5
# /data/ait/sac/2021-02-16/SAC013380.fits
# 6
# /data/ait/sac/2021-02-16/SAC013381.fits
# 7
# /data/ait/sac/2021-02-16/SAC013382.fits
# 8
# /data/ait/sac/2021-02-16/SAC013383.fits
# 9
# /data/ait/sac/2021-02-16/SAC013384.fits
# 10
# /data/ait/sac/2021-02-16/SAC013385.fits
# 11
# /data/ait/sac/2021-02-16/SAC013386.fits
# 12
# /data/ait/sac/2021-02-16/SAC013387.fits
# 13
# /data/ait/sac/2021-02-16/SAC013388.fits
# 14
# /data/ait/sac/2021-02-16/SAC013389.fits
# 15
# /data/ait/sac/2021-02-16/SAC013390.fits
# 16
# /data/ait/sac/2021-02-16/SAC013391.fits
# 17
# /data/ait/sac/2021-02-16/SAC013392.fits
# 18
# /data/ait/sac/2021-02-16/SAC013393.fits
# 19
# /data/ait/sac/2021-02-16/SAC013394.fits
# 20
# /data/ait/sac/2021-02-16/SAC013395.fits
# 21
# /data/ait/sac/2021-02-16/SAC013396.fits
# 22
# /data/ait/sac/2021-02-16/SAC013397.fits
# 23
# /data/ait/sac/2021-02-16/SAC013398.fits
# 24
# /data/ait/sac/2021-02-16/SAC013399.fits
# 25
# /data/ait/sac/2021-02-16/SAC013400.fits
# 26
# /data/ait/sac/2021-02-16/SAC013401.fits
# 27
# /data/ait/sac/2021-02-16/SAC013402.fits
# 28
# /data/ait/sac/2021-02-16/SAC013403.fits
# 29
# /data/ait/sac/2021-02-16/SAC013404.fits
# 30
# /data/ait/sac/2021-02-16/SAC013405.fits
# 31
# /data/ait/sac/2021-02-16/SAC013406.fits
# 32
# /data/ait/sac/2021-02-16/SAC013407.fits
# 33
# /data/ait/sac/2021-02-16/SAC013408.fits
# 34
# /data/ait/sac/2021-02-16/SAC013409.fits
# 35
# /data/ait/sac/2021-02-16/SAC013410.fits
# 36
# /data/ait/sac/2021-02-16/SAC013411.fits
# 37
# /data/ait/sac/2021-02-16/SAC013412.fits
# 38
# /data/ait/sac/2021-02-16/SAC013413.fits
# 39
# /data/ait/sac/2021-02-16/SAC013414.fits
# 40
# /data/ait/sac/2021-02-16/SAC013415.fits
# 41
# /data/ait/sac/2021-02-16/SAC013416.fits
# 42
# /data/ait/sac/2021-02-16/SAC013417.fits
# 43
# /data/ait/sac/2021-02-16/SAC013418.fits
# 44
# /data/ait/sac/2021-02-16/SAC013419.fits
# 45
# /data/ait/sac/2021-02-16/SAC013420.fits
# 46
# /data/ait/sac/2021-02-16/SAC013421.fits
# 47
# /data/ait/sac/2021-02-16/SAC013422.fits
# 48
# /data/ait/sac/2021-02-16/SAC013423.fits
# 49
# /data/ait/sac/2021-02-16/SAC013424.fits
# 50
# /data/ait/sac/2021-02-16/SAC013425.fits
# 51
# /data/ait/sac/2021-02-16/SAC013426.fits
# 52
# /data/ait/sac/2021-02-16/SAC013427.fits
# 53
# /data/ait/sac/2021-02-16/SAC013428.fits
# 54
# /data/ait/sac/2021-02-16/SAC013429.fits
# 55
# /data/ait/sac/2021-02-16/SAC013430.fits
# 56
# /data/ait/sac/2021-02-16/SAC013431.fits
# peak has not been properly detected
# 57
# /data/ait/sac/2021-02-16/SAC013432.fits
# 58
# /data/ait/sac/2021-02-16/SAC013433.fits
# peak has not been properly detected
# 59
# /data/ait/sac/2021-02-16/SAC013434.fits
# peak has not been properly detected
# 0
# /data/ait/sac/2021-02-16/SAC013435.fits
# peak has not been properly detected
# 1
# /data/ait/sac/2021-02-16/SAC013436.fits
# peak has not been properly detected
# 2
# /data/ait/sac/2021-02-16/SAC013437.fits
# peak has not been properly detected
# 3
# /data/ait/sac/2021-02-16/SAC013438.fits
# peak has not been properly detected
# 4
# /data/ait/sac/2021-02-16/SAC013439.fits
# 5
# /data/ait/sac/2021-02-16/SAC013440.fits
# 6
# /data/ait/sac/2021-02-16/SAC013441.fits
# 7
# /data/ait/sac/2021-02-16/SAC013442.fits
# 8
# /data/ait/sac/2021-02-16/SAC013443.fits
# 9
# /data/ait/sac/2021-02-16/SAC013444.fits
# 10
# /data/ait/sac/2021-02-16/SAC013445.fits
# 11
# /data/ait/sac/2021-02-16/SAC013446.fits
# 12
# /data/ait/sac/2021-02-16/SAC013447.fits
# 13
# /data/ait/sac/2021-02-16/SAC013448.fits
# 14
# /data/ait/sac/2021-02-16/SAC013449.fits
# 15
# /data/ait/sac/2021-02-16/SAC013450.fits
# 16
# /data/ait/sac/2021-02-16/SAC013451.fits
# 17
# /data/ait/sac/2021-02-16/SAC013452.fits
# 18
# /data/ait/sac/2021-02-16/SAC013453.fits
# 19
# /data/ait/sac/2021-02-16/SAC013454.fits
# 20
# /data/ait/sac/2021-02-16/SAC013455.fits
# 21
# /data/ait/sac/2021-02-16/SAC013456.fits
# 22
# /data/ait/sac/2021-02-16/SAC013457.fits
# 23
# /data/ait/sac/2021-02-16/SAC013458.fits
# 24
# /data/ait/sac/2021-02-16/SAC013459.fits
# 25
# /data/ait/sac/2021-02-16/SAC013460.fits
# 26
# /data/ait/sac/2021-02-16/SAC013461.fits
# 27
# /data/ait/sac/2021-02-16/SAC013462.fits
# 28
# /data/ait/sac/2021-02-16/SAC013463.fits
# 29
# /data/ait/sac/2021-02-16/SAC013464.fits
# 30
# /data/ait/sac/2021-02-16/SAC013465.fits
# 31
# /data/ait/sac/2021-02-16/SAC013466.fits
# 32
# /data/ait/sac/2021-02-16/SAC013467.fits
# 33
# /data/ait/sac/2021-02-16/SAC013468.fits
# 34
# /data/ait/sac/2021-02-16/SAC013469.fits
# 35
# /data/ait/sac/2021-02-16/SAC013470.fits
# 36
# /data/ait/sac/2021-02-16/SAC013471.fits
# 37
# /data/ait/sac/2021-02-16/SAC013472.fits
# 38
# /data/ait/sac/2021-02-16/SAC013473.fits
# 39
# /data/ait/sac/2021-02-16/SAC013474.fits
# 40
# /data/ait/sac/2021-02-16/SAC013475.fits
# 41
# /data/ait/sac/2021-02-16/SAC013476.fits
# 42
# /data/ait/sac/2021-02-16/SAC013477.fits
# 43
# /data/ait/sac/2021-02-16/SAC013478.fits
# 44
# /data/ait/sac/2021-02-16/SAC013479.fits
# 45
# /data/ait/sac/2021-02-16/SAC013480.fits
# 46
# /data/ait/sac/2021-02-16/SAC013481.fits
# 47
# /data/ait/sac/2021-02-16/SAC013482.fits
# 48
# /data/ait/sac/2021-02-16/SAC013483.fits
# 49
# /data/ait/sac/2021-02-16/SAC013484.fits
# 50
# /data/ait/sac/2021-02-16/SAC013485.fits
# 51
# /data/ait/sac/2021-02-16/SAC013486.fits
# 52
# /data/ait/sac/2021-02-16/SAC013487.fits
# 53
# /data/ait/sac/2021-02-16/SAC013488.fits
# 54
# /data/ait/sac/2021-02-16/SAC013489.fits
# 55
# /data/ait/sac/2021-02-16/SAC013490.fits
# 56
# /data/ait/sac/2021-02-16/SAC013491.fits
# 57
# /data/ait/sac/2021-02-16/SAC013492.fits
# 58
# /data/ait/sac/2021-02-16/SAC013493.fits
# 59
# /data/ait/sac/2021-02-16/SAC013494.fits

# %%
cube.plot(x='fca_x',y='EE20',style='*')

# %%
cube.set_index('fca_x').groupby("fiber")["EE20"].plot(legend=True,style='*')
# Out:
# fiber
# engbotend    AxesSubplot(0.125,0.125;0.775x0.755)
# engbotmid    AxesSubplot(0.125,0.125;0.775x0.755)
# engtopend    AxesSubplot(0.125,0.125;0.775x0.755)
# engtopmid    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: EE20, dtype: object

# %%
thres_neighbor = -0.1
doNeighborFilter = True

# %%
if doNeighborFilter :
    cube2 = imeas.neighbor_outlier_filter(cube,"EE20",thres_neighbor, absolute=True)

# %%
#cube2[cube2.EE20_diff_flag].groupby(["experimentId"]).plot(x='fca_x',y='EE20',style='*')
cube2[cube2.EE20_nbh_flag].set_index('fca_x').groupby("fiber")["EE20"].plot(legend=True,style='-*')
# Out:
# fiber
# engbotend    AxesSubplot(0.125,0.125;0.775x0.755)
# engbotmid    AxesSubplot(0.125,0.125;0.775x0.755)
# engtopend    AxesSubplot(0.125,0.125;0.775x0.755)
# engtopmid    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: EE20, dtype: object

# %%
def fitFocusData(cube, corrector=False, doPlot=False, index='fca_x'):
    thfoc_data = []
    
    for experimentId, series in cube.groupby('experimentId'):
        series = series.dropna()
        thfoc = getFocus(series, 'EE20', index, corrector=corrector)
#        for criteria in ['brightness', 'fwhm']:
#            thfoc[criteria] = getFocus(series, criteria, index, corrector=corrector)[criteria]

        thfoc['px'] = np.interp(thfoc[index], series[index], series['px'])
        thfoc['py'] = np.interp(thfoc[index], series[index], series['py'])
        thfoc['experimentId'] = experimentId
        thfoc['fiber'] = series['fiber'].unique()[0]

        thfoc_data.append(thfoc)
        
    thfoc_data = pd.concat(thfoc_data)

    if doPlot:
        kwargs = dict(grid=True, figsize=(14,10), legend=True, subplots=True)
#        criterias = ['EE20', 'brightness', 'fwhm']
        criterias = ['EE20']
        
        for experimentId, fit in thfoc_data.groupby('experimentId'):
            raw = cube.query("experimentId==%d"%(experimentId))
            axes = fit.set_index(index)[criterias].plot(**kwargs)
            for i, criteria in enumerate(criterias):
                axes[i].plot(raw[index].values, raw[criteria].values, 'o')
                
    return thfoc_data

# %%
thfocModel= fitFocusData(cube2[cube2.EE20_nbh_flag], corrector=False, doPlot=True)

# %%
def getFocusModel(fitdata, index='fca_x'):
    data = []
    for experimentId, series in fitdata.groupby('experimentId'):
        series = series.dropna()
        fiber = series['fiber'].unique()[0]
#        for criteria in ['EE20', 'brightness', 'fwhm']:
        for criteria in ['EE20']:

            ixmax = series[criteria].idxmax() if criteria !='fwhm' else series[criteria].idxmin()
            focus = series[index][ixmax]
            px = series.px[ixmax]
            py = series.py[ixmax]
            mat = [experimentId, criteria, px, py, focus, fiber]
            data.append(tuple(mat))
    
    return pd.DataFrame(data, columns=['experimentId', 'criteria', 'px', 'py', index,'fiber'])

# %%
focusModel = getFocusModel(thfocModel)

# %%
focusModel
# Out:
#    experimentId criteria           px          py     fca_x      fiber
# 0           447     EE20   995.347032  821.748943  0.200170  engtopend
# 1           448     EE20  1037.331317  891.453163  0.245375  engtopmid
# 2           449     EE20   996.433707  883.552185  0.256976  engbotmid
# 3           450     EE20  1071.484285  920.354923  0.663749  engbotend

# %%
vline = True
plotModel = True
criteria = 'EE20'
index = 'fca_x'

# %%
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(111)
j=2

if plotModel:
    ax1.plot(zemaxData.Slitdefocus, zemaxData.MidFiber, '+', color=colors[0], label='Zemax_MidFiber = %.3f' % zemaxMidFit.focus)
    ax1.plot(zemaxMidFit.x, zemaxMidFit.y, '--', color=colors[0])
    if vline:
        ax1.vlines(color=colors[0], **zemaxMidFit.vline)

    ax1.plot(zemaxData.Slitdefocus, zemaxData.ExtremeFiber, '+', color=colors[1], label='Zemax_EndFiber = %.3f' % zemaxEndFit.focus)
    ax1.plot(zemaxEndFit.x, zemaxEndFit.y, '--', color=colors[1])
    if vline:
        ax1.vlines(color=colors[1], **zemaxEndFit.vline)

for experimentId, df in cube2[cube2.EE20_nbh_flag].groupby('experimentId'):
    fit = thfocModel.query("experimentId==%d"%(experimentId))
    focus = focusModel.query("experimentId==%d and criteria=='%s'"%(experimentId, criteria))
    
    ax1.plot(df[index], df[criteria], 'o', color=colors[j], 
             label='expId%d:%s = %.3f' % (experimentId, experiments.fiber[experimentId], focus[index]))
    ax1.plot(fit[index], fit[criteria], '--', color=colors[j])
    
    if vline:
        ax1.vlines(x=focus[index], ymin=fit[criteria].min(), ymax = fit[criteria].max(), color=colors[j])
    j+=1

    
lns = [line for i, line in enumerate(ax1.get_lines()) if not i % 2]
labs = [line.get_label() for line in lns]

ax1.legend(lns, labs)
ax1.set_xlabel('%s(mm)'%index)
ax1.set_ylabel(criteria)

plt.title('Slit Through focus : Zemax vs Engineering_Fibers \n Criteria : %s doBck=True' %criteria)
plt.grid()

# %%
distance_fibres = 138.84
delta_focus = (1.086 - 0.633)
angle=np.arctan(delta_focus/distance_fibres)
angle_degre=(angle*180)/(np.pi)
print(angle_degre)
# Out:
# 0.18694105458441113

# %%
((0.648+0.658)/2) - 0.309
# Out:
# 0.34400000000000003

# %%
0.270-0.0062
# Out:
# 0.26380000000000003

# %%
1.532-0.885
# Out:
# 0.647
